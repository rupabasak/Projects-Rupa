# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import date
import warnings
warnings.filterwarnings('ignore')

# %%
end = date.today().strftime("%Y-%m-%d")
df = yf.download('RELIANCE.NS', start='2010-01-01', end=end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404   440.421997
# 2010-01-05   525.695618   525.695618   487.065033   489.488007   438.456360
# 2010-01-06   493.693939   500.368591   489.465149   497.397003   445.540802
# 2010-01-07   497.397003   509.740479   492.825348   505.648834   452.932312
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   451.744751
# ...                 ...          ...          ...          ...          ...
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000  2898.250000
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098  2948.600098
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000  2921.250000
# 2024-08-13  2921.500000  2940.149902  2916.000000  2927.250000  2927.250000
# 2024-08-14  2927.100098  2944.000000  2907.399902  2923.699951  2923.699951
#
#               Volume
# Date
# ...

# %%
reliance = df.drop(['Adj Close'], axis=1)
reliance
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404  38323043
# 2010-01-05   525.695618   525.695618   487.065033   489.488007  10696412
# 2010-01-06   493.693939   500.368591   489.465149   497.397003  11845880
# 2010-01-07   497.397003   509.740479   492.825348   505.648834  13098960
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   7555074
# ...                 ...          ...          ...          ...       ...
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000   6193596
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098   3124888
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000   4092292
# 2024-08-13  2921.500000  2940.149902  2916.000000  2927.250000   3132532
# 2024-08-14  2927.100098  2944.000000  2907.399902  2923.699951   3133733
#
# [3606 rows x 5 columns]

# %%
reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3606 entries, 2010-01-04 to 2024-08-14
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3606 non-null   float64
#  1   High    3606 non-null   float64
#  2   Low     3606 non-null   float64
#  3   Close   3606 non-null   float64
#  4   Volume  3606 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 169.0 KB

# %%
reliance.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  3606.000000  3606.000000  3606.000000  3606.000000  3.606000e+03
# mean   1087.830190  1099.265634  1075.738609  1087.039437  8.992760e+06
# std     823.256378   830.913013   815.213777   822.941449  6.211883e+06
# min     308.587280   312.153198   307.695831   309.090179  0.000000e+00
# 25%     428.216293   433.130844   423.141739   427.530540  5.475004e+06
# 50%     610.271362   615.985931   605.082550   609.722748  7.398546e+06
# 75%    1865.566986  1894.133789  1841.269012  1859.994385  1.035953e+07
# max    3208.899902  3217.600098  3171.000000  3201.800049  9.432482e+07

# %% [markdown]
# # EDA

# %%
reliance.duplicated().sum()
# Out:
# 0

# %%
reliance.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Creating Box Plots

# %%
plt.figure(figsize=(20,10))

# Plot 1
plt.subplot(2,2,1)
plt.boxplot(reliance['Open'])
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')

# Plot 2
plt.subplot(2,2,2)
plt.boxplot(reliance['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close')

# Plot 3
plt.subplot(2,2,3)
plt.boxplot(reliance['High'])
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')

# Plot 4
plt.subplot(2,2,4)
plt.boxplot(reliance['Low'])
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# From the Boxplot it is observed that there are no outliers in the dataset

# %% [markdown]
# # Visualization

# %%
import seaborn as sns

# %%
sns.set_style(style='darkgrid')

# %%
plt.figure(figsize=(20,10))

# Plot 1
plt.subplot(2,2,1)
plt.plot(reliance['Open'],color='green')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')

# Plot 2
plt.subplot(2,2,2)
plt.plot(reliance['Close'],color='red')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close')

# Plot 3
plt.subplot(2,2,3)
plt.plot(reliance['High'],color='blue')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')

# Plot 4
plt.subplot(2,2,4)
plt.plot(reliance['Low'],color='orange')
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# Histogram

# %%
plt.figure(figsize=(20,10))

# Plot 1
plt.subplot(2,2,1)
plt.hist(reliance['Open'],bins=50,color='green')
plt.xlabel('Open Price')
plt.ylabel('Frequency')
plt.title('Open')

# Plot 2
plt.subplot(2,2,2)
plt.hist(reliance['Close'],bins=50,color='red')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.title('Close')

# Plot 3
plt.subplot(2,2,3)
plt.hist(reliance['High'],bins=50,color='blue')
plt.xlabel('High Price')
plt.ylabel('Frequency')
plt.title('High')

# Plot 4
plt.subplot(2,2,4)
plt.hist(reliance['Low'],bins=50,color='orange')
plt.xlabel('Low Price')
plt.ylabel('Frequency')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# KDE Plots

# %%
plt.figure(figsize=(20,10))

#Plot 1
plt.subplot(2,2,1)
sns.kdeplot(reliance['Open'], color='green')
plt.title('Open')

#Plot 2
plt.subplot(2,2,2)
sns.kdeplot(reliance['Close'], color='red')
plt.title('Close')

#Plot 3
plt.subplot(2,2,3)
sns.kdeplot(reliance['High'], color='green')
plt.title('High')

#Plot 4
plt.subplot(2,2,4)
sns.kdeplot(reliance['Low'], color='red')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
plt.figure(figsize=(20,10))
plt.plot(reliance['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Date vs Volume')
plt.show()

# %%
# Moving Average

# %%
rel_ma = reliance.copy()
rel_ma['MA 30 day'] = rel_ma['Close'].rolling(window=30).mean()
rel_ma['MA 100 day'] = rel_ma['Close'].rolling(window=100).mean()
rel_ma
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404  38323043
# 2010-01-05   525.695618   525.695618   487.065033   489.488007  10696412
# 2010-01-06   493.693939   500.368591   489.465149   497.397003  11845880
# 2010-01-07   497.397003   509.740479   492.825348   505.648834  13098960
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   7555074
# ...                 ...          ...          ...          ...       ...
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000   6193596
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098   3124888
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000   4092292
# 2024-08-13  2921.500000  2940.149902  2916.000000  2927.250000   3132532
# 2024-08-14  2927.100098  2944.000000  2907.399902  2923.699951   3133733
#
#               MA 30 day   MA 100 day
# Date
# 2010-01-04          NaN          NaN
# ...

# %%
plt.figure(figsize=(20,10))
plt.plot(rel_ma['MA 30 day'],label='30 day')
plt.plot(rel_ma['Close'],label='Original data')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Close vs Moving Average 30 day')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(rel_ma['MA 100 day'],label='100 day')
plt.plot(rel_ma['Close'],label='Original data')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Close vs Moving Average 100 day')
plt.show()

# %%
# Long term and short term trends can be identified by Moving Average.
# There was huge downfall in 2020,may be for covid-19
# Long term trend is in higher side

# %%
plt.figure(figsize=(20,8))

# Candle Chart
plt.subplot(3,3,1)
plt.title('Candle Stick Chart')
plt.plot(reliance.index, reliance['Close'], color='black')
plt.fill_between(reliance.index, reliance['Open'], reliance['Close'], where = reliance['Close']>=reliance['Open'], color='green', alpha=0.4)
plt.fill_between(reliance.index, reliance['Open'], reliance['Close'], where= reliance['Close']<reliance['Open'], color='red', alpha=0.4)
plt.grid(True)

# Mountain Chart
plt.subplot(3,3,2)
plt.title('Mountain Chart')
plt.fill_between(reliance.index, reliance['Close'], color='black', alpha=0.3)
plt.grid(True)


# Color HCL Chart
plt.subplot(3,3,3)
plt.title('Color HCL Bar')
plt.fill_between(reliance.index, reliance['Close'], color='skyblue', alpha=0.5)
plt.plot(reliance['Close'], color='blue')
plt.grid(True)

plt.subplot(3,3,4)
plt.title('Histogram')
plt.hist(reliance['Close'], bins=30, color='orange')
plt.grid(True)

# Vertex Chart
plt.subplot(3,3,5)
plt.title('Vertex Chart')
plt.scatter(reliance.index, reliance['Close'], color='cyan', s=5)
plt.grid(True)

# Step Chart
plt.subplot(3,3,6)
plt.title('Step Chart')
plt.step(reliance.index, reliance['Close'], color='red')
plt.grid(True)

plt.tight_layout() 
plt.show()

# %%
reliance
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404  38323043
# 2010-01-05   525.695618   525.695618   487.065033   489.488007  10696412
# 2010-01-06   493.693939   500.368591   489.465149   497.397003  11845880
# 2010-01-07   497.397003   509.740479   492.825348   505.648834  13098960
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   7555074
# ...                 ...          ...          ...          ...       ...
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000   6193596
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098   3124888
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000   4092292
# 2024-08-13  2921.500000  2940.149902  2916.000000  2927.250000   3132532
# 2024-08-14  2927.100098  2944.000000  2907.399902  2923.699951   3133733
#
# [3606 rows x 5 columns]

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Prophet

# %%
data = df[['Close']]
data
# Out:
#                   Close
# Date
# 2010-01-04   491.682404
# 2010-01-05   489.488007
# 2010-01-06   497.397003
# 2010-01-07   505.648834
# 2010-01-08   504.323059
# ...                 ...
# 2024-08-08  2898.250000
# 2024-08-09  2948.600098
# 2024-08-12  2921.250000
# 2024-08-13  2927.250000
# 2024-08-14  2923.699951
#
# [3606 rows x 1 columns]

# %%
data.reset_index(inplace=True)

# %%
data.rename(columns={'Date':'ds', 'Close':'y'}, inplace=True)
data
# Out:
#              ds            y
# 0    2010-01-04   491.682404
# 1    2010-01-05   489.488007
# 2    2010-01-06   497.397003
# 3    2010-01-07   505.648834
# 4    2010-01-08   504.323059
# ...         ...          ...
# 3601 2024-08-08  2898.250000
# 3602 2024-08-09  2948.600098
# 3603 2024-08-12  2921.250000
# 3604 2024-08-13  2927.250000
# 3605 2024-08-14  2923.699951
#
# [3606 rows x 2 columns]

# %%
from prophet import Prophet
model_pr = Prophet()

# %%
model_pr.fit(data)
# Out:
# 14:51:19 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:20 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Checking Seasonality
model_pr.component_modes
# Out:
# {'additive': ['yearly',
#   'weekly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
future_date = model_pr.make_future_dataframe(periods=30)
future_date.tail()
# Out:
#              ds
# 3631 2024-09-09
# 3632 2024-09-10
# 3633 2024-09-11
# 3634 2024-09-12
# 3635 2024-09-13

# %%
forecast = model_pr.predict(future_date)
forecast.tail(30)
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 3606 2024-08-15  2810.312119  2683.035204  2970.575911  2810.312119
# 3607 2024-08-16  2810.994431  2701.164794  2959.981763  2810.994431
# 3608 2024-08-17  2811.676742  2677.217422  2960.431432  2811.676742
# 3609 2024-08-18  2812.359054  2712.370577  2987.922151  2812.359054
# 3610 2024-08-19  2813.041365  2688.846423  2968.431066  2813.041365
# 3611 2024-08-20  2813.723677  2698.940122  2967.179596  2813.723677
# 3612 2024-08-21  2814.405988  2700.051967  2964.075422  2814.405988
# 3613 2024-08-22  2815.088299  2689.068569  2963.779475  2815.088299
# 3614 2024-08-23  2815.770611  2694.410855  2958.093376  2815.770611
# 3615 2024-08-24  2816.452922  2700.579597  2974.930763  2816.452922
# 3616 2024-08-25  2817.135234  2712.852687  2983.767639  2817.135234
# 3617 2024-08-26  2817.817545  2702.525882  2957.923747  2817.817545
# 3618 2024-08-27  2818.499857  2699.391308  2979.176552  2818.499857
# ...

# %%
fig = model_pr.plot(forecast)
plt.title('Reliance Stock Price Prediction for Next 30 Days using Prophet')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
# In this Graph:
# 1. The Black scatter plot is our actual data.
# 2. The Blue lineplot is the prediction.

# %%
fig2 = model_pr.plot_components(forecast)

# %%
# In this Graph:
# 1. It is basically checking the seasonality of the data.
# 2. Prophet have taken seasonality for weekly and yearly.

# %%
# Cross Validation
from prophet.diagnostics import cross_validation

# %%
df_cv = cross_validation(model_pr, initial='730 days', period='180 days', horizon='365 days')
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# 14:51:21 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:21 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:21 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:21 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] done processing
# 14:51:22 - cmdstanpy - INFO - Chain [1] start processing
# 14:51:23 - cmdstanpy - INFO - Chain [1] done processing
# ...

# %%
# 1. model: The Prophet model that has been fitted to the data.

# 2. initial: The size of the initial training period. 
#             This is the duration from the start of the time series data to the first cutoff point.

# 3. period: The spacing between cutoff dates.
#            This defines how often the model will be retrained and tested on a new subset of data.

# 4. horizon: The forecast horizon. 
#             This is the duration for which the forecast is made from each cutoff point.

# %%
df_cv.head()
# Out:
#           ds        yhat  yhat_lower  yhat_upper           y     cutoff
# 0 2012-04-16  355.565488  335.693727  376.244011  342.006165 2012-04-14
# 1 2012-04-17  354.976688  334.597211  375.790074  341.228973 2012-04-14
# 2 2012-04-18  354.859726  334.757529  375.604759  342.234741 2012-04-14
# 3 2012-04-19  353.086276  332.793676  373.175158  339.057434 2012-04-14
# 4 2012-04-20  351.331715  330.459592  371.897262  334.120026 2012-04-14

# %%
from prophet.diagnostics import performance_metrics

# %%
df_p = performance_metrics(df_cv)
df_p
# Out:
#      horizon           mse        rmse         mae      mape     mdape  \
# 0    39 days  31285.853780  176.878076  113.202449  0.098283  0.074236
# 1    40 days  32181.021716  179.390696  114.864070  0.099212  0.074811
# 2    41 days  32651.649009  180.697673  115.677644  0.099665  0.075532
# 3    42 days  32351.788137  179.866028  114.880830  0.099570  0.075702
# 4    43 days  32901.694752  181.388243  115.836575  0.100025  0.075532
# ..       ...           ...         ...         ...       ...       ...
# 322 361 days  57424.157351  239.633381  179.303181  0.159263  0.145084
# 323 362 days  57015.839791  238.779898  178.819240  0.159653  0.145084
# 324 363 days  56979.829652  238.704482  179.213477  0.160351  0.147499
# 325 364 days  57479.602990  239.749042  180.367804  0.160760  0.150145
# 326 365 days  57795.185500  240.406293  181.152412  0.161103  0.150145
#
#         smape  coverage
# 0    0.096271  0.322034
# 1    0.097278  0.323729
# 2    0.097628  0.324633
# ...

# %%
# 1. MDAPE = Mean Directional Accuracy Percentage Error.
# 2. MAPE = Mean Absolute Percentage Error.
# 3. sMAPE = Symmetric Mean Absolute Percentage Error.
# 4. Coverage is basically difference between yhat lower and yhat upper.

# %%
from prophet.plot import plot_cross_validation_metric

# %%
fig3 = plot_cross_validation_metric(df_cv, metric='rmse')

# %%
# This plot is trend with respect to error and it is plotted for RMSE.

# %%
# Checking Seasonality

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller,acf,pacf
from statsmodels.tsa.arima_model import ARIMA
period=365
result= seasonal_decompose(df['Close'],model='multiplicative',period=period)

# %%
result.seasonal.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
result.trend.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
result.resid.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# Our data is seasonal

# %%
# conducting dickey fuller test to check stationary.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result = adfuller(df['Close'])

# %%
# ho: The data is not stationary.
# ha: The data is stationary.

# %%
def adfullet_test(Close):
    result = adfuller(Close)
    labels = ['ADF Test', 'P-value', 'Lags Used', 'Number Of Observation']
    for value, label in zip(result, labels):
        print(label + ': ' + str(value))
    if result[1] <= 0.05:
        print("Null Hypothesis is rejected. The data is Stationary")
    else:
        print("Null Hypothesis is accepted. The data is not Stationary")

# %%
adfullet_test(df['Close'])
# Out:
# ADF Test: 0.6835736276222635
# P-value: 0.9895042872728148
# Lags Used: 3
# Number Of Observation: 3602
# Null Hypothesis is accepted. The data is not Stationary

# %%
# The assumption is rejected. (0.99 !<= 0.05)

# %%
# Differenceing

# %%
df['Close_Diff'] = df['Close'] - df['Close'].shift(12)

# %%
df.head(20)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2010-01-04  498.814209  498.814209  467.155457  491.682404  440.421997
# 2010-01-05  525.695618  525.695618  487.065033  489.488007  438.456360
# 2010-01-06  493.693939  500.368591  489.465149  497.397003  445.540802
# 2010-01-07  497.397003  509.740479  492.825348  505.648834  452.932312
# 2010-01-08  506.540314  509.191895  501.054321  504.323059  451.744751
# 2010-01-11  518.746643  525.604187  480.024689  494.425415  442.878998
# 2010-01-12  500.597168  519.935303  492.368164  495.728333  444.046112
# 2010-01-13  497.397003  499.225647  488.527954  497.671295  445.786469
# 2010-01-14  496.482666  514.220703  496.482666  512.803528  459.341125
# 2010-01-15  514.677856  520.666748  505.191681  507.797516  454.856964
# 2010-01-18  506.083160  510.403381  499.202789  502.654419  450.250031
# 2010-01-19  502.882996  505.648834  494.951172  496.025513  444.312286
# ...

# %%
adfullet_test(df['Close_Diff'].dropna())
# Out:
# ADF Test: -10.239567564462563
# P-value: 4.788894001924541e-18
# Lags Used: 29
# Number Of Observation: 3564
# Null Hypothesis is rejected. The data is Stationary

# %%
plt.figure(figsize=(10,7))
df['Close_Diff'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Close'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm

# %%
# Autocorrelation
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Close_Diff'].iloc[13:],lags=40,ax=ax1)

# Partial Autocorrelation
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Close_Diff'].iloc[13:],lags=40,ax=ax2)  
plt.show()

# %%
# Seasonal and Non_seasonal components are marked

# %% [markdown]
# # Sarimax

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings('ignore')

# %%
data2 = df[['Close']]
data2
# Out:
#                   Close
# Date
# 2010-01-04   491.682404
# 2010-01-05   489.488007
# 2010-01-06   497.397003
# 2010-01-07   505.648834
# 2010-01-08   504.323059
# ...                 ...
# 2024-08-08  2898.250000
# 2024-08-09  2948.600098
# 2024-08-12  2921.250000
# 2024-08-13  2927.250000
# 2024-08-14  2923.699951
#
# [3606 rows x 1 columns]

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
data2['Close'] = scale.fit_transform(data2[['Close']])

# %%
model = SARIMAX(data2, order=(1,1,1), seasonal_order=(1,1,1,12))
model

# %%
model_fit = model.fit(disp=False) 
print(model_fit.summary())
# Out:
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Close   No. Observations:                 3606
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 12)   Log Likelihood                7869.027
# Date:                            Thu, 15 Aug 2024   AIC                         -15728.053
# Time:                                    14:51:41   BIC                         -15697.120
# Sample:                                         0   HQIC                        -15717.028
#                                            - 3606
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.0072      1.142     -0.006      0.995      -2.246       2.232
# ma.L1         -0.0017      1.143     -0.002      0.999      -2.241       2.238
# ...

# %%
forecast_steps = 30
forecast = model_fit.get_forecast(steps=forecast_steps)
forecast_index = pd.date_range(start=data2.index[-1], periods=forecast_steps + 1, freq='B')[1:]
forecast_values = scale.inverse_transform(forecast.predicted_mean.values.reshape(-1, 1))

# %%
forecast_df = pd.DataFrame(data=forecast_values, index=forecast_index, columns=['Forecast'])
forecast_df
# Out:
#                Forecast
# 2024-08-15  2929.213661
# 2024-08-16  2933.297311
# 2024-08-19  2937.808485
# 2024-08-20  2932.573569
# 2024-08-21  2929.248604
# 2024-08-22  2929.564331
# 2024-08-23  2927.969058
# 2024-08-26  2925.163873
# 2024-08-27  2928.809055
# 2024-08-28  2931.545413
# 2024-08-29  2935.726948
# 2024-08-30  2935.088026
# 2024-09-02  2940.837211
# 2024-09-03  2945.187147
# 2024-09-04  2949.490743
# 2024-09-05  2944.619730
# 2024-09-06  2942.666114
# 2024-09-09  2942.748443
# 2024-09-10  2940.892385
# 2024-09-11  2938.476704
# 2024-09-12  2941.485693
# 2024-09-13  2944.631874
# 2024-09-16  2948.788639
# 2024-09-17  2948.189372
# 2024-09-18  2953.941764
# 2024-09-19  2958.295327
# 2024-09-20  2962.596096
# 2024-09-23  2957.730039
# 2024-09-24  2955.795104
# 2024-09-25  2955.874253

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(forecast_df, s=100)
plt.xlabel('Date')
plt.ylabel('Forecast')
plt.title('Forecast Data')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(forecast_df, color='orange', linestyle='--', marker='*')
plt.xlabel('Date')
plt.ylabel('Forecast')
plt.title('Forecast Data')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(data2.index, scale.inverse_transform(data2), label='Actual')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecast')
plt.title('Reliance Stock Price Prediction for Next 30 Days using SARIMAX')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Calculate RMSE

# %%
from sklearn.metrics import mean_squared_error
actual = data2['Close'][1:]
predicted = model_fit.fittedvalues[1:]

rmse = np.sqrt(mean_squared_error(actual, predicted))
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")
# Out:
# Root Mean Squared Error (RMSE): 0.0275

# %%
# Calculate MSE

# %%
from sklearn.metrics import mean_squared_error
actual = data2['Close'][1:]
predicted = model_fit.fittedvalues[1:]

mse = mean_squared_error(actual, predicted)
print(f"Root Mean Squared Error (RMSE): {mse:.4f}")
# Out:
# Root Mean Squared Error (RMSE): 0.0008

# %%
# Calculate MAE

# %%
from sklearn.metrics import mean_absolute_error
actual = data2['Close'][1:]  
predicted = model_fit.fittedvalues[1:]

mae = mean_absolute_error(actual, predicted)
print(f"Mean Absolute Error (MAE): {mae:.4f}")
# Out:
# Mean Absolute Error (MAE): 0.0162

# %%
# Calculate MAPE

# %%
actual = data2['Close'][1:]  
predicted = model_fit.fittedvalues[1:]
mape = np.mean(np.abs((actual - predicted) / actual)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
# Out:
# Mean Absolute Percentage Error (MAPE): 9.18%

# %%
dict_err = {
    'MSE': [0.0008 ],
    
    'MAE': [0.0162 ],

    'RMSE': [0.0276],

    'MAPE': [6.90 ]
}

# %%
df_err = pd.DataFrame(dict_err,index=['SARIMAX'])
df_err
# Out:
#             MSE     MAE    RMSE  MAPE
# SARIMAX  0.0008  0.0162  0.0276   6.9

# %%
# The errors in Prophet model are much higher side than SARIMAX,hence the deployment can be done with SARIMAX

# %%
file = 'model.pkl'

# %%
import pickle

# %%
pickle.dump(model,open(file,'wb'))

# %%
# Supriya: Dataset and EDA (1 to 11)
# Shreyash: Visualization (12 to 25)
# Tanu: Prophet (26 to 38)
# Indranil: Cross Validation (39 to 49)
# Aditya: Seasonality (50 to 69)
# Rupa: Sarimax (70 to end)
# Milind: Deployment
